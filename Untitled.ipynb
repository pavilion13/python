# %%
a = 1000
while a != 0:
    if a % 10 == 1 and a < 110 and (a % 100) != 11:
        print(a , " программист")
    elif 2 <= (a % 10) <= 4 and a < 110 and (a % 100) != 12 and (a % 100) != 13 and (a % 100) != 14:
        print(a , " программиста")
    else:
        print(a , " программистов")
    a -= 1
# Out:
# 1000  программистов
# 999  программистов
# 998  программистов
# 997  программистов
# 996  программистов
# 995  программистов
# 994  программистов
# 993  программистов
# 992  программистов
# 991  программистов
# 990  программистов
# 989  программистов
# 988  программистов
# 987  программистов
# 986  программистов
# 985  программистов
# 984  программистов
# 983  программистов
# 982  программистов
# 981  программистов
# 980  программистов
# 979  программистов
# 978  программистов
# 977  программистов
# 976  программистов
# 975  программистов
# 974  программистов
# 973  программистов
# 972  программистов
# 971  программистов
# 970  программистов
# 969  программистов
# 968  программистов
# 967  программистов
# 966  программистов
# 965  программистов
# 964  программистов
# 963  программистов
# 962  программистов
# 961  программистов
# 960  программистов
# 959  программистов
# 958  программистов
# 957  программистов
# 956  программистов
# 955  программистов
# 954  программистов
# ...
